# %%
# Import the Ticket class
from Ticket import Ticket

class Visitor:
    def __init__(self, id, name, age):
        """
        Initializes a Visitor object with the given ID, name, and age.

        Args:
            id (int): The ID of the visitor.
            name (str): The name of the visitor.
            age (int): The age of the visitor.
        """
        self._id = id
        self._name = name
        self._age = age
        self._ticket_purchased = []

    def get_id(self):
        """
        Gets the ID of the visitor.

        Returns:
            int: The ID of the visitor.
        """
        return self._id

    def set_id(self, id):
        """
        Sets the ID of the visitor.

        Args:
            id (int): The new ID for the visitor.
        """
        self._id = id

    def get_name(self):
        """
        Gets the name of the visitor.

        Returns:
            str: The name of the visitor.
        """
        return self._name

    def set_name(self, name):
        """
        Sets the name of the visitor.

        Args:
            name (str): The new name for the visitor.
        """
        self._name = name

    def get_age(self):
        """
        Gets the age of the visitor.

        Returns:
            int: The age of the visitor.
        """
        return self._age

    def set_age(self, age):
        """
        Sets the age of the visitor.

        Args:
            age (int): The new age for the visitor.
        """
        self._age = age

    def get_ticket_purchased(self):
        """
        Gets the list of tickets purchased by the visitor.

        Returns:
            list: The list of tickets purchased by the visitor.
        """
        return self._ticket_purchased

    def purchase_ticket(self, event):
        """
        Purchases a ticket for the given event and adds it to the list of purchased tickets.

        Args:
            event (str): The event for which the ticket is purchased.
        """
        ticket = Ticket(event, price)  # Create a new ticket object
        self._ticket_purchased.append(ticket)  # Add the ticket to the list of purchased tickets

    def display_ticket(self):
        """
        Displays the tickets purchased by the visitor.
        """
        if not self._ticket_purchased:
            print("No tickets purchased")
        else:
            print("Tickets Purchased:")
            for ticket in self._ticket_purchased:
                print(f"Event: {ticket.get_event()}, Price: {ticket.get_price()}")
